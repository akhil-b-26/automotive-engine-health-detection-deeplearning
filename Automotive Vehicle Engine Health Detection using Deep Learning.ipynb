# %%
# Import necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.preprocessing import StandardScaler
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
# Load the data
data = pd.read_csv("/content/engine_health_dataset_corrected_new.csv")

# %%
# Data overview
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Engine rpm        10000 non-null  float64
#  1   lub oil pressure  10000 non-null  float64
#  2   fuel pressure     10000 non-null  float64
#  3   coolant pressure  10000 non-null  float64
#  4   lub oil temp      10000 non-null  float64
#  5   coolant temp      10000 non-null  float64
#  6   Engine Condition  10000 non-null  int64
# dtypes: float64(6), int64(1)
# memory usage: 547.0 KB

# %%
data .head()
# Out:
#     Engine rpm  lub oil pressure  fuel pressure  coolant pressure  \
# 0   958.393341         34.021854      51.229376         13.494198
# 1  2062.954700         57.310678      97.057067         13.706153
# 2  1631.860381         22.537377      54.679742         13.796871
# 3   631.843696         40.574268      47.260420         15.943171
# 4  2253.602780         29.462712      43.915756         13.962658
#
#    lub oil temp  coolant temp  Engine Condition
# 0    193.009312    195.578416                 1
# 1    182.179533    205.615296                 0
# 2    264.421723    194.259755                 0
# 3    195.672472    187.835875                 1
# 4    131.107633    181.813635                 0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Engine rpm'].plot(kind='hist', bins=20, title='Engine rpm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['lub oil pressure'].plot(kind='hist', bins=20, title='lub oil pressure')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['fuel pressure'].plot(kind='hist', bins=20, title='fuel pressure')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='index', y='Engine rpm', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='Engine rpm', y='lub oil pressure', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='lub oil pressure', y='fuel pressure', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='fuel pressure', y='coolant pressure', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['Engine rpm']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('Engine rpm')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['lub oil pressure']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('lub oil pressure')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['fuel pressure']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('fuel pressure')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['coolant pressure']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('coolant pressure')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['Engine rpm'].plot(kind='line', figsize=(8, 4), title='Engine rpm')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['lub oil pressure'].plot(kind='line', figsize=(8, 4), title='lub oil pressure')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['fuel pressure'].plot(kind='line', figsize=(8, 4), title='fuel pressure')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
data.describe()
# Out:
#          Engine rpm  lub oil pressure  fuel pressure  coolant pressure  \
# count  10000.000000      10000.000000   10000.000000      10000.000000
# mean    1852.316312         40.194714      49.977298         14.536619
# std      923.404010         13.940546      11.563362          2.298618
# min        5.643290          0.048582       0.120928          0.101689
# 25%     1176.795722         29.284105      42.174977         13.714396
# 50%     1806.743426         39.994316      49.952967         14.539546
# 75%     2442.714164         50.525075      57.959701         15.309954
# max     7992.655683         99.911253      99.982445         29.982486
#
#        lub oil temp  coolant temp  Engine Condition
# count  10000.000000  10000.000000       10000.00000
# mean     199.208045    193.547932           0.70000
# std       23.578716     23.883537           0.45828
# min        2.570551      0.140606           0.00000
# 25%      189.405421    187.217340           0.00000
# 50%      200.119487    194.970437           1.00000
# 75%      210.682494    202.984454           1.00000
# max      299.618512    299.827757           1.00000

# %%
# Data visualization
sns.histplot(data[data['Engine Condition'] == 0]['Engine rpm'], color='red')
sns.histplot(data[data['Engine Condition'] == 1]['Engine rpm'], color='blue')
plt.legend(labels=["Engine Condition = 0", "engine condition = 1"])
plt.title('Engine rpm', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Engine rpm')

# %%
# Repeat similar plots for other features
sns.histplot(data[data['Engine Condition'] == 0]['lub oil pressure'], color='red')
sns.histplot(data[data['Engine Condition'] == 1]['lub oil pressure'], color='blue')
plt.legend(labels=["Engine Condition = 0", "Engine Condition = 1"])
plt.title('Lub oil pressure', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Lub oil pressure')

# %%
sns.histplot(data[data['Engine Condition'] == 0]['fuel pressure'], color='red')
sns.histplot(data[data['Engine Condition'] == 1]['fuel pressure'], color='blue')
plt.legend(labels=["Engine Condition = 0", "Engine Condition = 1"])
plt.title('Fuel pressure', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Fuel pressure')

# %%
# Additional feature plots (Coolant pressure, lub oil temp, Coolant temp, etc.)
# Correlation analysis
corr = data.corr()
sns.heatmap(corr, annot=True)
plt.title('Correlation', fontsize=18)
# Out:
# Text(0.5, 1.0, 'Correlation')

# %%
# Train-validation-test split
X = data.drop('Engine Condition', axis=1)
y = data['Engine Condition']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.12, random_state=42)
X_validation, X_test, y_validation, y_test = train_test_split(X_test, y_test, test_size=0.33, random_state=42)

# %%
# Display dataset shapes
print("train set shape:", X_train.shape)
print("validation set shape:", X_validation.shape)
print("test set shape:", X_test.shape)
# Out:
# train set shape: (8800, 6)
# validation set shape: (804, 6)
# test set shape: (396, 6)

# %%
# Normalize features
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_validation = scaler.transform(X_validation)
X_test = scaler.transform(X_test)

# %%
# Deep Learning Model - Neural Network
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))  # Increased number of neurons
model.add(Dropout(0.5))  # Increased dropout rate to prevent overfitting
model.add(Dense(64, activation='relu'))  # Additional hidden layer
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  # Output layer for binary classification
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7113 - loss: 0.5829 - val_accuracy: 0.9254 - val_loss: 0.2103
# Epoch 2/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9015 - loss: 0.2669 - val_accuracy: 0.9341 - val_loss: 0.1650
# Epoch 3/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9125 - loss: 0.2146 - val_accuracy: 0.9465 - val_loss: 0.1487
# Epoch 4/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9258 - loss: 0.1905 - val_accuracy: 0.9540 - val_loss: 0.1398
# Epoch 5/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9240 - loss: 0.1965 - val_accuracy: 0.9453 - val_loss: 0.1476
# Epoch 6/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9267 - loss: 0.1862 - val_accuracy: 0.9403 - val_loss: 0.1513
# Epoch 7/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9310 - loss: 0.1846 - val_accuracy: 0.9565 - val_loss: 0.1368
# Epoch 8/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9335 - loss: 0.1689 - val_accuracy: 0.9453 - val_loss: 0.1439
# Epoch 9/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9352 - loss: 0.1619 - val_accuracy: 0.9490 - val_loss: 0.1300
# Epoch 10/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9373 - loss: 0.1624 - val_accuracy: 0.9490 - val_loss: 0.1334
# Epoch 11/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9438 - loss: 0.1504 - val_accuracy: 0.9515 - val_loss: 0.1327
# Epoch 12/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9403 - loss: 0.1600 - val_accuracy: 0.9565 - val_loss: 0.1216
# Epoch 13/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9457 - loss: 0.1547 - val_accuracy: 0.9565 - val_loss: 0.1210
# Epoch 14/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9485 - loss: 0.1367 - val_accuracy: 0.9602 - val_loss: 0.1120
# Epoch 15/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9528 - loss: 0.1312 - val_accuracy: 0.9590 - val_loss: 0.1137
# Epoch 16/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9560 - loss: 0.1226 - val_accuracy: 0.9602 - val_loss: 0.1086
# Epoch 17/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9559 - loss: 0.1198 - val_accuracy: 0.9602 - val_loss: 0.1086
# Epoch 18/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9599 - loss: 0.1130 - val_accuracy: 0.9677 - val_loss: 0.0943
# Epoch 19/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9603 - loss: 0.1059 - val_accuracy: 0.9627 - val_loss: 0.0985
# Epoch 20/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9609 - loss: 0.1099 - val_accuracy: 0.9664 - val_loss: 0.0882
# Epoch 21/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9655 - loss: 0.1012 - val_accuracy: 0.9701 - val_loss: 0.0808
# Epoch 22/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9716 - loss: 0.0854 - val_accuracy: 0.9701 - val_loss: 0.0753
# Epoch 23/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9732 - loss: 0.0805 - val_accuracy: 0.9751 - val_loss: 0.0697
# Epoch 24/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9708 - loss: 0.0832 - val_accuracy: 0.9813 - val_loss: 0.0582
# Epoch 25/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9740 - loss: 0.0728 - val_accuracy: 0.9701 - val_loss: 0.0711
# Epoch 26/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9754 - loss: 0.0773 - val_accuracy: 0.9838 - val_loss: 0.0498
# Epoch 27/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9720 - loss: 0.0741 - val_accuracy: 0.9826 - val_loss: 0.0530
# Epoch 28/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9712 - loss: 0.0720 - val_accuracy: 0.9888 - val_loss: 0.0465
# Epoch 29/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9802 - loss: 0.0569 - val_accuracy: 0.9863 - val_loss: 0.0441
# Epoch 30/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9751 - loss: 0.0746 - val_accuracy: 0.9863 - val_loss: 0.0471
# Epoch 31/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9817 - loss: 0.0553 - val_accuracy: 0.9838 - val_loss: 0.0478
# Epoch 32/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9845 - loss: 0.0487 - val_accuracy: 0.9863 - val_loss: 0.0408
# Epoch 33/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9838 - loss: 0.0507 - val_accuracy: 0.9913 - val_loss: 0.0357
# Epoch 34/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9838 - loss: 0.0494 - val_accuracy: 0.9888 - val_loss: 0.0370
# Epoch 35/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9836 - loss: 0.0516 - val_accuracy: 0.9863 - val_loss: 0.0328
# Epoch 36/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9870 - loss: 0.0446 - val_accuracy: 0.9863 - val_loss: 0.0361
# Epoch 37/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9861 - loss: 0.0427 - val_accuracy: 0.9876 - val_loss: 0.0326
# Epoch 38/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9853 - loss: 0.0406 - val_accuracy: 0.9925 - val_loss: 0.0289
# Epoch 39/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9872 - loss: 0.0376 - val_accuracy: 0.9938 - val_loss: 0.0314
# Epoch 40/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9884 - loss: 0.0392 - val_accuracy: 0.9925 - val_loss: 0.0268
# Epoch 41/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9876 - loss: 0.0372 - val_accuracy: 0.9925 - val_loss: 0.0251
# Epoch 42/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9885 - loss: 0.0356 - val_accuracy: 0.9925 - val_loss: 0.0248
# Epoch 43/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9913 - loss: 0.0252 - val_accuracy: 0.9938 - val_loss: 0.0216
# Epoch 44/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9894 - loss: 0.0313 - val_accuracy: 0.9913 - val_loss: 0.0260
# Epoch 45/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9884 - loss: 0.0359 - val_accuracy: 0.9888 - val_loss: 0.0252
# Epoch 46/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9908 - loss: 0.0278 - val_accuracy: 0.9938 - val_loss: 0.0249
# Epoch 47/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9923 - loss: 0.0309 - val_accuracy: 0.9900 - val_loss: 0.0284
# Epoch 48/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9943 - loss: 0.0233 - val_accuracy: 0.9925 - val_loss: 0.0311
# Epoch 49/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9909 - loss: 0.0328 - val_accuracy: 0.9963 - val_loss: 0.0193
# Epoch 50/50
# 275/275 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9923 - loss: 0.0282 - val_accuracy: 0.9938 - val_loss: 0.0217

# %%
# Evaluate model on the test set
y_pred = (model.predict(X_test) > 0.5).astype("int32")
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)

cm = confusion_matrix(y_test, y_pred)
ConfusionMatrixDisplay(confusion_matrix=cm).plot()
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Accuracy: 0.9949494949494949
# Precision: 0.9928571428571429
# Recall: 1.0

# %%
# Function to predict engine condition
def check_engine_condition(new_input):
    new_input = scaler.transform([new_input])
    prediction = model.predict(new_input)
    return "Healthy" if prediction[0] >= 0.5 else "Unhealthy"

new_input1 = [2166,26.6,40.4,14.9,187.9,204.3]
new_input2 = [1951.4,2.8,50.1,14.1,190,209.4]
  # Modify these values as needed
result1 = check_engine_condition(new_input1)
print("The engine is:", result1)
result2 = check_engine_condition(new_input2)
print("The engine is:", result2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# The engine is: Healthy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# The engine is: Unhealthy
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
